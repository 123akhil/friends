# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_colwidth', -1)

# %%
# import re
# friends_chars={} 
# Rachel=''
# Ross=''
# Joey=''
# Chandler=''
# Phoebe=''
# Monica=''
# with open("transcripts_friends/season_all/merged.csv", "r+") as fp:
#     for cnt, line in enumerate(fp):
#         if line.startswith('Rachel:'):
#             string=(line[8:].replace(":", "").replace('"', '').replace("'", "").replace(",", ""))
#             Rachel=Rachel+re.sub(r'\(.*\)', '', string)
#         elif line.startswith('Ross:'):
#             string=(line[6:].replace(":", "").replace('"', '').replace("'", "").replace(",", ""))
#             Ross=Ross+re.sub(r'\(.*\)', '', string)
#         elif line.startswith('Monica:'):
#             string=(line[8:].replace(":", "").replace('"', '').replace("'", "").replace(",", ""))
#             Monica=Monica+re.sub(r'\(.*\)', '', string)
#         elif line.startswith('Chandler:'):#             string=(line[10:].replace(":", "").replace('"', '').replace(",", ""))
#             Chandler=Chandler+re.sub(r'\(.*\)', '', string)
#         if line.startswith('Phoebe:'):
#             string=(line[8:].replace(":", "").replace('"', '').replace("'", "").replace(",", ""))
#             Phoebe=Phoebe+re.sub(r'\(.*\)', '', string)
#         if line.startswith('Joey:'):
#             string=(line[6:].replace(":", "").replace('"', '').replace("'", "").replace(",", ""))
#             Joey=Joey+re.sub(r'\(.*\)', '', string)

# friends_chars['RACHEL']=Rachel
# friends_chars['ROSS']=Ross
# friends_chars['MONICA']=Monica
# friends_chars['PHOEBE']=Phoebe
# friends_chars['CHANDLER']=Chandler
# friends_chars['JOEY']=Joey

# %%
import re
friends_chars={} 
Rachel=''
Ross=''
Joey=''
Chandler=''
Phoebe=''
Monica=''
Scene=''
with open("transcripts_friends/season1/merged1.csv", "r+") as fp:
    for cnt, line in enumerate(fp):
        if line.startswith('[Scene:'):
            Scene=(line[7:].replace("]", "").replace(":", ",").replace(".", ","))
        if line.startswith('Rachel:'):
            string=Scene.replace("\n", "")+"*"+(line[8:].replace(":", "").replace('"', '').replace("'", "").replace(",", ""))
            Rachel=Rachel+re.sub(r'\(.*\)', '', string)
        elif line.startswith('Ross:'):
            string="("+"Scene:"+Scene.replace("\n", "")+")"+(line[6:].replace(":", "").replace('"', '').replace("'", "").replace(",", ""))
            Ross=Ross+re.sub(r'\(.*\)', '', string)
        elif line.startswith('Monica:'):
            string="("+"Scene:"+Scene.replace("\n", "")+")"+(line[8:].replace(":", "").replace('"', '').replace("'", "").replace(",", ""))
            Monica=Monica+re.sub(r'\(.*\)', '', string)
        elif line.startswith('Chandler:'):
            string="("+"Scene:"+Scene.replace("\n", "")+")"+(line[10:].replace(":", "").replace('"', '').replace(",", ""))
            Chandler=Chandler+re.sub(r'\(.*\)', '', string)
        if line.startswith('Phoebe:'):
            string="("+"Scene:"+Scene.replace("\n", "")+")"+(line[8:].replace(":", "").replace('"', '').replace("'", "").replace(",", ""))
            Phoebe=Phoebe+re.sub(r'\(.*\)', '', string)
        if line.startswith('Joey:'):
            string="("+"Scene:"+Scene.replace("\n", "")+")"+(line[6:].replace(":", "").replace('"', '').replace("'", "").replace(",", ""))
            Joey=Joey+re.sub(r'\(.*\)', '', string)

friends_chars['RACHEL']=Rachel
friends_chars['ROSS']=Ross
friends_chars['MONICA']=Monica
friends_chars['PHOEBE']=Phoebe
friends_chars['CHANDLER']=Chandler
friends_chars['JOEY']=Joey

s=pd.Series(friends_chars['RACHEL'].split('\n'))
df1 = pd.DataFrame({'Text':s.values})

df1 = pd.DataFrame(df1.Text.str.split('*',1).tolist(),
                                   columns = ['Scene','Text'])

s=df1.Text
df1=  pd.DataFrame(df1.Scene.str.split(',',1).tolist(),
                                   columns = ['Location','Scene'])
df1['Text']=s
df1['Speaker']='Rachel'
df1['Season']='1'

df1.head(30)

#print(scene_text)
# Out:
#                Location                                            Scene  \
# 0    Central Perk         Chandler, Joey, Phoebe, and Monica are there,
# 1    Central Perk         Chandler, Joey, Phoebe, and Monica are there,
# 2    Central Perk         Chandler, Joey, Phoebe, and Monica are there,
# 3    Central Perk         Chandler, Joey, Phoebe, and Monica are there,
# 4    Central Perk         Chandler, Joey, Phoebe, and Monica are there,
# 5    Central Perk         Chandler, Joey, Phoebe, and Monica are there,
# 6    Central Perk         Chandler, Joey, Phoebe, and Monica are there,
# 7    Central Perk         Chandler, Joey, Phoebe, and Monica are there,
# 8    Central Perk         Chandler, Joey, Phoebe, and Monica are there,
# 9    Central Perk         Chandler, Joey, Phoebe, and Monica are there,
# 10   Central Perk         Chandler, Joey, Phoebe, and Monica are there,
# 11   Central Perk         Chandler, Joey, Phoebe, and Monica are there,
# 12   A Restaurant         Monica and Paul are eating,
# 13   Monica's Apartment   Rachel is watching Joanne Loves Chaci,
# 14   Monica's Apartment   Rachel is making coffee for Joey and Chandler,
# 15   Monica's Apartment   Rachel is making coffee for Joey and Chandler,
# 16   Monica's Apartment   Rachel is making coffee for Joey and Chandler,
# 17   Monica's Apartment   Rachel is making coffee for Joey and Chandler,
# 18   Monica's Apartment   Rachel is making coffee for Joey and Chandler,
# 19   Monica's Apartment   Rachel is making coffee for Joey and Chandler,
# 20   Monica's Apartment   Rachel is making coffee for Joey and Chandler,
# 21   Monica's Apartment   Rachel is making coffee for Joey and Chandler,
# 22   Monica's Apartment   Rachel is making coffee for Joey and Chandler,
# 23   Monica's Apartment   Rachel is making coffee for Joey and Chandler,
# 24   Monica's Apartment   Rachel is making coffee for Joey and Chandler,
# 25   Central Perk         everyone but Rachel is there,
# 26   Central Perk         everyone but Rachel is there,
# 27   Central Perk         everyone but Rachel is there,
# 28   Central Perk         everyone but Rachel is there,
# 29   Central Perk         everyone but Rachel is there,
#
#                                                                                                                                                                                                                                                                                                                                                                                       Text  \
# 0   Oh God Monica hi! Thank God! I just went to your building and you werent there and then this guy with a big hammer said you might be here and you are you are!
# 1   Hi sure!
# 2   Oh God... well it started about a half hour before the wedding. I was in the room where we were keeping all the presents and I was looking at this gravy boat. This really gorgeous Lamauge gravy boat. When all of a sudden-  So anyway I just didnt know where to go and I know that you and I have kinda drifted apart but youre the only person I knew who lived here in the city.
# 3   Ooh I was kinda hoping that wouldnt be an issue... [Scene Monicas Apartment everyone is there and watching a Spanish Soap on TV and are trying to figure out what is going on.]
# 4    Daddy I just... I cant marry him! Im sorry. I just dont love him. Well it matters to me!
# %%
import re
friends_chars={} 
Rachel=''
Ross=''
Joey=''
Chandler=''
Phoebe=''
Monica=''
Scene=''
with open("transcripts_friends/season2/merged2.csv", "r+") as fp:
    for cnt, line in enumerate(fp):
        if line.startswith('[Scene:'):
            Scene=(line[7:].replace("]", "").replace(":", ",").replace(".", ","))
        if line.startswith('Rachel:'):
            string=Scene.replace("\n", "")+"*"+(line[8:].replace(":", ""))
            Rachel=Rachel+re.sub(r'\(.*\)', '', string)
        elif line.startswith('Ross:'):
            string=Scene.replace("\n", "")+"*"+(line[6:].replace(":", ""))
            Ross=Ross+re.sub(r'\(.*\)', '', string)
        elif line.startswith('Monica:'):
            string=Scene.replace("\n", "")+"*"+(line[8:].replace(":", ""))
            Monica=Monica+re.sub(r'\(.*\)', '', string)
        elif line.startswith('Chandler:'):
            string=Scene.replace("\n", "")+"*"+(line[10:].replace(":", ""))
            Chandler=Chandler+re.sub(r'\(.*\)', '', string)
        if line.startswith('Phoebe:'):
            string=Scene.replace("\n", "")+"*"+(line[8:].replace(":", ""))
            Phoebe=Phoebe+re.sub(r'\(.*\)', '', string)
        if line.startswith('Joey:'):
            string=Scene.replace("\n", "")+"*"+(line[6:].replace(":", ""))
            Joey=Joey+re.sub(r'\(.*\)', '', string)


friends_chars['RACHEL']=Rachel
friends_chars['ROSS']=Ross
friends_chars['MONICA']=Monica
friends_chars['PHOEBE']=Phoebe
friends_chars['CHANDLER']=Chandler
friends_chars['JOEY']=Joey

s=pd.Series(friends_chars['RACHEL'].split('\n'))
df1 = pd.DataFrame({'Text':s.values})
df1 = pd.DataFrame(df1.Text.str.split('*',1).tolist(), columns = ['Scene','Text'])
s=df1.Text
df1=  pd.DataFrame(df1.Scene.str.split(',',1).tolist(),
                                   columns = ['Location','Scene'])
df1['Text']=s
df1['Speaker']='Rachel'
df1['Season']='2'
df1.head(20)

s2=pd.Series(friends_chars['ROSS'].split('\n'))
df2 = pd.DataFrame({'Text':s2.values})
df2 = pd.DataFrame(df2.Text.str.split('*',1).tolist(), columns = ['Scene','Text'])
s=df2.Text
df2=  pd.DataFrame(df2.Scene.str.split(',',1).tolist(),
                                   columns = ['Location','Scene'])
df1['Text']=s
df2['Speaker']='Ross'
df2['Season']='2' 
df2.head(20)

s3=pd.Series(friends_chars['MONICA'].split('\n'))
df3 = pd.DataFrame({'Text':s3.values})
df3 = pd.DataFrame(df3.Text.str.split('*',1).tolist(), columns = ['Scene','Text'])
s=df3.Text
df3=  pd.DataFrame(df3.Scene.str.split(',',1).tolist(),
                                   columns = ['Location','Scene'])
df3['Text']=s
df3['Speaker']='Monica'
df3['Season']='2'                         
df3.head(20)

s4=pd.Series(friends_chars['JOEY'].split('\n'))
df4 = pd.DataFrame({'Text':s4.values})
df4 = pd.DataFrame(df4.Text.str.split('*',1).tolist(), columns = ['Scene','Text'])
s=df4.Text
df4=  pd.DataFrame(df4.Scene.str.split(',',1).tolist(),
                                   columns = ['Location','Scene'])
df4['Text']=s
df4['Speaker']='Joey'
df4['Season']='2'                            
df4.head(20)

s5=pd.Series(friends_chars['PHOEBE'].split('\n'))
df5 = pd.DataFrame({'Text':s5.values})
df5 = pd.DataFrame(df5.Text.str.split('*',1).tolist(), columns = ['Scene','Text'])
s=df5.Text
df5=  pd.DataFrame(df5.Scene.str.split(',',1).tolist(),
                                   columns = ['Location','Scene'])
df5['Text']=s
df5['Speaker']='Phoebe'
df5['Season']='2'                           
df5.head(20)

s6=pd.Series(friends_chars['CHANDLER'].split('\n'))
df6 = pd.DataFrame({'Text':s6.values})
df6 = pd.DataFrame(df6.Text.str.split('*',1).tolist(), columns = ['Scene','Text'])
s=df6.Text
df6=  pd.DataFrame(df6.Scene.str.split(',',1).tolist(),
                                   columns = ['Location','Scene'])
df6['Text']=s
df6['Speaker']='Chandler'
df6['Season']='2'                            
df6.head(20)

df_2 = pd.concat([df1, df2,df3,df4,df5,df6])
df_2 = df_2.sample(frac=1).reset_index(drop=True)

df_2.head()
# Out:
# C:\Users\LENOVO\Anaconda3\lib\site-packages\ipykernel_launcher.py:107: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#                Location  \
# 0   Monica and Rachel's
# 1   Monica's bedroom
# 2   Monica's bedroom
# 3   Monica and Rachel's
# 4   Central Perk
#
#                                                                                                      Scene  \
# 0   Monica is recovering from her haircut, Phoebe is playing her doctor and is coming in from the bedroom,
# 1   Phoebe is finishing with her haircut and Monica is whincing,
# 2   Phoebe is finishing with her haircut and Monica is whincing,
# 3   Carol and Susan are showing off Ben to the gang,
# 4   Phoebe is there as Monica enters,
#
#   Season Speaker  \
# 0  2      Rachel
# 1  2      Monica
# 2  2      Monica
# 3  2      Joey
# 4  2      Phoebe
#
#                                                                                  Text
# 0  Yes, yes it is. In prison! Whatsa matter with you?
# 1  That's Dudley Moore. I said I wanted it like Demi Moore.
# 2  How who wears it?
# 3  Ok, I got one, I got one. Uh, if he blows into one, does the other one get bigger?
# 4  Oh, all right. What did I have?

# %%
import re
friends_chars={} 
Rachel=''
Ross=''
Joey=''
Chandler=''
Phoebe=''
Monica=''
Scene=''
with open("transcripts_friends/season3/merged3.csv", "r+",encoding="utf8") as fp:
    for cnt, line in enumerate(fp):
        if line.startswith('[Scene:'):
            Scene=(line[7:].replace("]", "").replace(":", ",").replace(".", ","))
        if line.startswith('Rachel:'):
            string=Scene.replace("\n", "")+"*"+(line[8:].replace(":", ""))
            Rachel=Rachel+re.sub(r'\(.*\)', '', string)
        elif line.startswith('Ross:'):
            string=Scene.replace("\n", "")+"*"+(line[6:].replace(":", ""))
            Ross=Ross+re.sub(r'\(.*\)', '', string)
        elif line.startswith('Monica:'):
            string=Scene.replace("\n", "")+"*"+(line[8:].replace(":", ""))
            Monica=Monica+re.sub(r'\(.*\)', '', string)
        elif line.startswith('Chandler:'):
            string=Scene.replace("\n", "")+"*"+(line[10:].replace(":", ""))
            Chandler=Chandler+re.sub(r'\(.*\)', '', string)
        if line.startswith('Phoebe:'):
            string=Scene.replace("\n", "")+"*"+(line[8:].replace(":", ""))
            Phoebe=Phoebe+re.sub(r'\(.*\)', '', string)
        if line.startswith('Joey:'):
            string=Scene.replace("\n", "")+"*"+(line[6:].replace(":", ""))
            Joey=Joey+re.sub(r'\(.*\)', '', string)


friends_chars['RACHEL']=Rachel
friends_chars['ROSS']=Ross
friends_chars['MONICA']=Monica
friends_chars['PHOEBE']=Phoebe
friends_chars['CHANDLER']=Chandler
friends_chars['JOEY']=Joey

s=pd.Series(friends_chars['RACHEL'].split('\n'))
df1 = pd.DataFrame({'Text':s.values})
df1 = pd.DataFrame(df1.Text.str.split('*',1).tolist(), columns = ['Scene','Text'])
s=df1.Text
df1=  pd.DataFrame(df1.Scene.str.split(',',1).tolist(),
                                   columns = ['Location','Scene'])
df1['Text']=s
df1['Speaker']='Rachel'
df1['Season']='3'
df1.head(20)

s2=pd.Series(friends_chars['ROSS'].split('\n'))
df2 = pd.DataFrame({'Text':s2.values})
df2 = pd.DataFrame(df2.Text.str.split('*',1).tolist(), columns = ['Scene','Text'])
s=df2.Text
df2=  pd.DataFrame(df2.Scene.str.split(',',1).tolist(),
                                   columns = ['Location','Scene'])
df2['Text']=s
df2['Speaker']='Ross'
df2['Season']='3' 
df2.head(20)

s3=pd.Series(friends_chars['MONICA'].split('\n'))
df3 = pd.DataFrame({'Text':s3.values})
df3 = pd.DataFrame(df3.Text.str.split('*',1).tolist(), columns = ['Scene','Text'])
s=df3.Text
df3=  pd.DataFrame(df3.Scene.str.split(',',1).tolist(),
                                   columns = ['Location','Scene'])
df3['Text']=s
df3['Speaker']='Monica'
df3['Season']='3'                         
df3.head(20)

s4=pd.Series(friends_chars['JOEY'].split('\n'))
df4 = pd.DataFrame({'Text':s4.values})
df4 = pd.DataFrame(df4.Text.str.split('*',1).tolist(), columns = ['Scene','Text'])
s=df4.Text
df4=  pd.DataFrame(df4.Scene.str.split(',',1).tolist(),
                                   columns = ['Location','Scene'])
df4['Text']=s
df4['Speaker']='Joey'
df4['Season']='3'                            
df4.head(20)

s5=pd.Series(friends_chars['PHOEBE'].split('\n'))
df5 = pd.DataFrame({'Text':s5.values})
df5 = pd.DataFrame(df5.Text.str.split('*',1).tolist(), columns = ['Scene','Text'])
s=df5.Text
df5=  pd.DataFrame(df5.Scene.str.split(',',1).tolist(),
                                   columns = ['Location','Scene'])
df5['Text']=s
df5['Speaker']='Phoebe'
df5['Season']='3'                           
df5.head(20)

s6=pd.Series(friends_chars['CHANDLER'].split('\n'))
df6 = pd.DataFrame({'Text':s6.values})
df6 = pd.DataFrame(df6.Text.str.split('*',1).tolist(), columns = ['Scene','Text'])
s=df6.Text
df6=  pd.DataFrame(df6.Scene.str.split(',',1).tolist(),
                                   columns = ['Location','Scene'])
df6['Text']=s
df6['Speaker']='Chandler'
df6['Season']='3'                            
df6.head(20)

df_3 = pd.concat([df1, df2,df3,df4,df5,df6])
df_3 = df_3.sample(frac=1).reset_index(drop=True)

df_3.head()
# Out:
#                               Location  \
# 0   The Ultimate Fighting Championship
# 1   A bar
# 2   A Restaurant
# 3   Monica and Rachel's
# 4   the hallway
#
#                                                                                                      Scene  \
# 0   Ross and Monica are there watching Pete,
# 1   Chandler is entering,
# 2   Monica and Phoebe are on their dates with Sergei and Mischa,
# 3   Chandler, Ross, Joey, and Rachel are eating breakfast, Chandler is holding a bottle of Hersey’s Syrup,
# 4   Joey is moving in, Monica is leaving,
#
#                                                                                                      Text  \
# 0  Yeah, it’s the Ultimate Fighting Combo. Yeah, I saved thirty cents, plus I get to keep the cup. Yay!!
# 1  Hey-hey-hey. You wanna hear something that sucks.
# 2  Monica, can I talk to you behind my menu, please.  What are you doing?
# 3  Oh, um, around 802. We ah, talked for a little while, and then um, we went out for an innocent burger.
# 4  Gotcha.
#
#   Speaker Season
# 0  Ross    3
# 1  Monica  3
# 2  Phoebe  3
# 3  Monica  3
# 4  Joey    3

# %%
import re
friends_chars={} 
Rachel=''
Ross=''
Joey=''
Chandler=''
Phoebe=''
Monica=''
Scene=''
with open("transcripts_friends/season4/merged4.csv", "r+",encoding="utf8") as fp:
    for cnt, line in enumerate(fp):
        if line.startswith('[Scene:'):
            Scene=(line[7:].replace("]", "").replace(":", ",").replace(".", ","))
        if line.startswith('Rachel:'):
            string=Scene.replace("\n", "")+"*"+(line[8:].replace(":", ""))
            Rachel=Rachel+re.sub(r'\(.*\)', '', string)
        elif line.startswith('Ross:'):
            string=Scene.replace("\n", "")+"*"+(line[6:].replace(":", ""))
            Ross=Ross+re.sub(r'\(.*\)', '', string)
        elif line.startswith('Monica:'):
            string=Scene.replace("\n", "")+"*"+(line[8:].replace(":", ""))
            Monica=Monica+re.sub(r'\(.*\)', '', string)
        elif line.startswith('Chandler:'):
            string=Scene.replace("\n", "")+"*"+(line[10:].replace(":", ""))
            Chandler=Chandler+re.sub(r'\(.*\)', '', string)
        if line.startswith('Phoebe:'):
            string=Scene.replace("\n", "")+"*"+(line[8:].replace(":", ""))
            Phoebe=Phoebe+re.sub(r'\(.*\)', '', string)
        if line.startswith('Joey:'):
            string=Scene.replace("\n", "")+"*"+(line[6:].replace(":", ""))
            Joey=Joey+re.sub(r'\(.*\)', '', string)


friends_chars['RACHEL']=Rachel
friends_chars['ROSS']=Ross
friends_chars['MONICA']=Monica
friends_chars['PHOEBE']=Phoebe
friends_chars['CHANDLER']=Chandler
friends_chars['JOEY']=Joey

s=pd.Series(friends_chars['RACHEL'].split('\n'))
df1 = pd.DataFrame({'Text':s.values})
df1 = pd.DataFrame(df1.Text.str.split('*',1).tolist(), columns = ['Scene','Text'])
s=df1.Text
df1=  pd.DataFrame(df1.Scene.str.split(',',1).tolist(),
                                   columns = ['Location','Scene'])
df1['Text']=s
df1['Speaker']='Rachel'
df1['Season']='4'
df1.head(20)

s2=pd.Series(friends_chars['ROSS'].split('\n'))
df2 = pd.DataFrame({'Text':s2.values})
df2 = pd.DataFrame(df2.Text.str.split('*',1).tolist(), columns = ['Scene','Text'])
s=df2.Text
df2=  pd.DataFrame(df2.Scene.str.split(',',1).tolist(),
                                   columns = ['Location','Scene'])
df2['Text']=s
df2['Speaker']='Ross'
df2['Season']='4' 
df2.head(20)

s3=pd.Series(friends_chars['MONICA'].split('\n'))
df3 = pd.DataFrame({'Text':s3.values})
df3 = pd.DataFrame(df3.Text.str.split('*',1).tolist(), columns = ['Scene','Text'])
s=df3.Text
df3=  pd.DataFrame(df3.Scene.str.split(',',1).tolist(),
                                   columns = ['Location','Scene'])
df3['Text']=s
df3['Speaker']='Monica'
df3['Season']='4'                         
df3.head(20)

s4=pd.Series(friends_chars['JOEY'].split('\n'))
df4 = pd.DataFrame({'Text':s4.values})
df4 = pd.DataFrame(df4.Text.str.split('*',1).tolist(), columns = ['Scene','Text'])
s=df4.Text
df4=  pd.DataFrame(df4.Scene.str.split(',',1).tolist(),
                                   columns = ['Location','Scene'])
df4['Text']=s
df4['Speaker']='Joey'
df4['Season']='4'                            
df4.head(20)

s5=pd.Series(friends_chars['PHOEBE'].split('\n'))
df5 = pd.DataFrame({'Text':s5.values})
df5 = pd.DataFrame(df5.Text.str.split('*',1).tolist(), columns = ['Scene','Text'])
s=df5.Text
df5=  pd.DataFrame(df5.Scene.str.split(',',1).tolist(),
                                   columns = ['Location','Scene'])
df5['Text']=s
df5['Speaker']='Phoebe'
df5['Season']='4'                           
df5.head(20)

s6=pd.Series(friends_chars['CHANDLER'].split('\n'))
df6 = pd.DataFrame({'Text':s6.values})
df6 = pd.DataFrame(df6.Text.str.split('*',1).tolist(), columns = ['Scene','Text'])
s=df6.Text
df6=  pd.DataFrame(df6.Scene.str.split(',',1).tolist(),
                                   columns = ['Location','Scene'])
df6['Text']=s
df6['Speaker']='Chandler'
df6['Season']='4'                            
df6.head(20)

df_4 = pd.concat([df1, df2,df3,df4,df5,df6])
df_4 = df_4.sample(frac=1).reset_index(drop=True)

df_4.head()
# Out:
#                    Location  \
# 0   Monica and Rachel's
# 1   Monica and Rachel's
# 2   Monica and Rachel's
# 3   Monica and Rachel's erm
# 4   Monica and Rachel's
#
#                                                                                                                                       Scene  \
# 0   the gang is watching the Prom Video and Rachel is about to make her entrance on the video,  The italics are portions of the prom video,
# 1   continued from earlier, everyone is still eating breakfast,
# 2   erm, Chandler and Joey's, Ross, Joey, and Phoebe are watching a movie as Chandler comes in from his bedroom,
# 3   Chandler and Joey's, Ross is writing on the Magna-Doodle as Rachel enters,
# 4   it’s later that morning, everybody has gotten up and Ross and Phoebe has joined them for breakfast, Rachel is returning from shopping,
#
#                                                                                                          Text  \
# 0  You don’t have a car. And your license expired.
# 1  All right! I’ll try! But if I can’t, you can stay with Chandler and I until you get settled.
# 2  That’s not backing me up! Look, you said with the off-stage and the heat, and the onstage and the oy heat.
# 3  Does for me.
# 4  No-no, not for like another two weeks.
#
#     Speaker Season
# 0  Monica    4
# 1  Joey      4
# 2  Chandler  4
# 3  Chandler  4
# 4  Joey      4

# %%
import re
friends_chars={} 
Rachel=''
Ross=''
Joey=''
Chandler=''
Phoebe=''
Monica=''
Scene=''
with open("transcripts_friends/season5/merged5.csv", "r+") as fp:
    for cnt, line in enumerate(fp):
        if line.startswith('[Scene:'):
            Scene=(line[7:].replace("]", "").replace(":", ",").replace(".", ","))
        if line.startswith('Rachel:'):
            string=Scene.replace("\n", "")+"*"+(line[8:].replace(":", ""))
            Rachel=Rachel+re.sub(r'\(.*\)', '', string)
        elif line.startswith('Ross:'):
            string=Scene.replace("\n", "")+"*"+(line[6:].replace(":", ""))
            Ross=Ross+re.sub(r'\(.*\)', '', string)
        elif line.startswith('Monica:'):
            string=Scene.replace("\n", "")+"*"+(line[8:].replace(":", ""))
            Monica=Monica+re.sub(r'\(.*\)', '', string)
        elif line.startswith('Chandler:'):
            string=Scene.replace("\n", "")+"*"+(line[10:].replace(":", ""))
            Chandler=Chandler+re.sub(r'\(.*\)', '', string)
        if line.startswith('Phoebe:'):
            string=Scene.replace("\n", "")+"*"+(line[8:].replace(":", ""))
            Phoebe=Phoebe+re.sub(r'\(.*\)', '', string)
        if line.startswith('Joey:'):
            string=Scene.replace("\n", "")+"*"+(line[6:].replace(":", ""))
            Joey=Joey+re.sub(r'\(.*\)', '', string)


friends_chars['RACHEL']=Rachel
friends_chars['ROSS']=Ross
friends_chars['MONICA']=Monica
friends_chars['PHOEBE']=Phoebe
friends_chars['CHANDLER']=Chandler
friends_chars['JOEY']=Joey

s=pd.Series(friends_chars['RACHEL'].split('\n'))
df1 = pd.DataFrame({'Text':s.values})
df1 = pd.DataFrame(df1.Text.str.split('*',1).tolist(), columns = ['Scene','Text'])
s=df1.Text
df1=  pd.DataFrame(df1.Scene.str.split(',',1).tolist(),
                                   columns = ['Location','Scene'])
df1['Text']=s
df1['Speaker']='Rachel'
df1['Season']='5'
df1.head(20)

s2=pd.Series(friends_chars['ROSS'].split('\n'))
df2 = pd.DataFrame({'Text':s2.values})
df2 = pd.DataFrame(df2.Text.str.split('*',1).tolist(), columns = ['Scene','Text'])
s=df2.Text
df2=  pd.DataFrame(df2.Scene.str.split(',',1).tolist(),
                                   columns = ['Location','Scene'])
df2['Text']=s
df2['Speaker']='Ross'
df2['Season']='5' 
df2.head(20)

s3=pd.Series(friends_chars['MONICA'].split('\n'))
df3 = pd.DataFrame({'Text':s3.values})
df3 = pd.DataFrame(df3.Text.str.split('*',1).tolist(), columns = ['Scene','Text'])
s=df3.Text
df3=  pd.DataFrame(df3.Scene.str.split(',',1).tolist(),
                                   columns = ['Location','Scene'])
df3['Text']=s
df3['Speaker']='Monica'
df3['Season']='5'                         
df3.head(20)

s4=pd.Series(friends_chars['JOEY'].split('\n'))
df4 = pd.DataFrame({'Text':s4.values})
df4 = pd.DataFrame(df4.Text.str.split('*',1).tolist(), columns = ['Scene','Text'])
s=df4.Text
df4=  pd.DataFrame(df4.Scene.str.split(',',1).tolist(),
                                   columns = ['Location','Scene'])
df4['Text']=s
df4['Speaker']='Joey'
df4['Season']='5'                            
df4.head(20)

s5=pd.Series(friends_chars['PHOEBE'].split('\n'))
df5 = pd.DataFrame({'Text':s5.values})
df5 = pd.DataFrame(df5.Text.str.split('*',1).tolist(), columns = ['Scene','Text'])
s=df5.Text
df5=  pd.DataFrame(df5.Scene.str.split(',',1).tolist(),
                                   columns = ['Location','Scene'])
df5['Text']=s
df5['Speaker']='Phoebe'
df5['Season']='5'                           
df5.head(20)

s6=pd.Series(friends_chars['CHANDLER'].split('\n'))
df6 = pd.DataFrame({'Text':s6.values})
df6 = pd.DataFrame(df6.Text.str.split('*',1).tolist(), columns = ['Scene','Text'])
s=df6.Text
df6=  pd.DataFrame(df6.Scene.str.split(',',1).tolist(),
                                   columns = ['Location','Scene'])
df6['Text']=s
df6['Speaker']='Chandler'
df6['Season']='5'                            
df6.head(20)

df_5 = pd.concat([df1, df2,df3,df4,df5,df6])
df_5 = df_5.sample(frac=1).reset_index(drop=True)

df_5.head()
# Out:
#                Location  \
# 0   Central Perk
# 1   Central Perk
# 2   Ross's Apartment
# 3   The casino
# 4   Monica and Rachel's
#
#                                                                                                                                                                                        Scene  \
# 0   Ross is drinking some Alka-Seltzer, The rest of the gang, minus Rachel is there as well,
# 1   Phoebe and Rachel are there talking about Chandler and Monica,
# 2   the gang is helping Ross move out by carrying boxes, Chandler has picked a particularly large and apparently heavy box, because he takes a running start at it and still can't budge it,
# 3   Ross and Rachel are entering,
# 4   Ross is returning from his horrible trek back home without pants on, The whole gang is there,
#
#                                                                                                                                                          Text  \
# 0  I told ya.
# 1  Well actually you're the one person I can't tell this too. And the one person I want to the most.
# 2  We all hate Emily!
# 3   Thanks man.
# 4  Okay, I'm gonna go too. I'm gonna go to the airport. I figure if I hang around there long enough, someone's bound to leave one of those planes unattended.
#
#   Speaker Season
# 0  Joey    5
# 1  Phoebe  5
# 2  Joey    5
# 3  Ross    5
# 4  Phoebe  5

# %%
import re
friends_chars={} 
Rachel=''
Ross=''
Joey=''
Chandler=''
Phoebe=''
Monica=''
Scene=''
with open("transcripts_friends/season6/merged6.csv", "r+",encoding="utf8") as fp:
    for cnt, line in enumerate(fp):
        if line.startswith('[Scene:'):
            Scene=(line[7:].replace("]", "").replace(":", ",").replace(".", ","))
        if line.startswith('Rachel:'):
            string=Scene.replace("\n", "")+"*"+(line[8:].replace(":", ""))
            Rachel=Rachel+re.sub(r'\(.*\)', '', string)
        elif line.startswith('Ross:'):
            string=Scene.replace("\n", "")+"*"+(line[6:].replace(":", ""))
            Ross=Ross+re.sub(r'\(.*\)', '', string)
        elif line.startswith('Monica:'):
            string=Scene.replace("\n", "")+"*"+(line[8:].replace(":", ""))
            Monica=Monica+re.sub(r'\(.*\)', '', string)
        elif line.startswith('Chandler:'):
            string=Scene.replace("\n", "")+"*"+(line[10:].replace(":", ""))
            Chandler=Chandler+re.sub(r'\(.*\)', '', string)
        if line.startswith('Phoebe:'):
            string=Scene.replace("\n", "")+"*"+(line[8:].replace(":", ""))
            Phoebe=Phoebe+re.sub(r'\(.*\)', '', string)
        if line.startswith('Joey:'):
            string=Scene.replace("\n", "")+"*"+(line[6:].replace(":", ""))
            Joey=Joey+re.sub(r'\(.*\)', '', string)


friends_chars['RACHEL']=Rachel
friends_chars['ROSS']=Ross
friends_chars['MONICA']=Monica
friends_chars['PHOEBE']=Phoebe
friends_chars['CHANDLER']=Chandler
friends_chars['JOEY']=Joey

s=pd.Series(friends_chars['RACHEL'].split('\n'))
df1 = pd.DataFrame({'Text':s.values})
df1 = pd.DataFrame(df1.Text.str.split('*',1).tolist(), columns = ['Scene','Text'])
s=df1.Text
df1=  pd.DataFrame(df1.Scene.str.split(',',1).tolist(),
                                   columns = ['Location','Scene'])
df1['Text']=s
df1['Speaker']='Rachel'
df1['Season']='6'
df1.head(20)

s2=pd.Series(friends_chars['ROSS'].split('\n'))
df2 = pd.DataFrame({'Text':s2.values})
df2 = pd.DataFrame(df2.Text.str.split('*',1).tolist(), columns = ['Scene','Text'])
s=df2.Text
df2=  pd.DataFrame(df2.Scene.str.split(',',1).tolist(),
                                   columns = ['Location','Scene'])
df2['Text']=s
df2['Speaker']='Ross'
df2['Season']='6' 
df2.head(20)

s3=pd.Series(friends_chars['MONICA'].split('\n'))
df3 = pd.DataFrame({'Text':s3.values})
df3 = pd.DataFrame(df3.Text.str.split('*',1).tolist(), columns = ['Scene','Text'])
s=df3.Text
df3=  pd.DataFrame(df3.Scene.str.split(',',1).tolist(),
                                   columns = ['Location','Scene'])
df3['Text']=s
df3['Speaker']='Monica'
df3['Season']='6'                         
df3.head(20)

s4=pd.Series(friends_chars['JOEY'].split('\n'))
df4 = pd.DataFrame({'Text':s4.values})
df4 = pd.DataFrame(df4.Text.str.split('*',1).tolist(), columns = ['Scene','Text'])
s=df4.Text
df4=  pd.DataFrame(df4.Scene.str.split(',',1).tolist(),
                                   columns = ['Location','Scene'])
df4['Text']=s
df4['Speaker']='Joey'
df4['Season']='6'                            
df4.head(20)

s5=pd.Series(friends_chars['PHOEBE'].split('\n'))
df5 = pd.DataFrame({'Text':s5.values})
df5 = pd.DataFrame(df5.Text.str.split('*',1).tolist(), columns = ['Scene','Text'])
s=df5.Text
df5=  pd.DataFrame(df5.Scene.str.split(',',1).tolist(),
                                   columns = ['Location','Scene'])
df5['Text']=s
df5['Speaker']='Phoebe'
df5['Season']='6'                           
df5.head(20)

s6=pd.Series(friends_chars['CHANDLER'].split('\n'))
df6 = pd.DataFrame({'Text':s6.values})
df6 = pd.DataFrame(df6.Text.str.split('*',1).tolist(), columns = ['Scene','Text'])
s=df6.Text
df6=  pd.DataFrame(df6.Scene.str.split(',',1).tolist(),
                                   columns = ['Location','Scene'])
df6['Text']=s
df6['Speaker']='Chandler'
df6['Season']='6'                            
df6.head(20)

df_6 = pd.concat([df1, df2,df3,df4,df5,df6])
df_6 = df_6.sample(frac=1).reset_index(drop=True)

df_6.head()
# Out:
#                        Location  \
# 0   Central Perk
# 1   A Restaurant
# 2   Joey and Rachel's apartment
# 3   Monica and Chandler’s
# 4   Monica and Chandler's
#
#                                                                                                                                                                                                                     Scene  \
# 0   Rachel is sitting at the counter waiting for Gunther, yep Gunther’s back, to refill her coffee,
# 1   Monica and Chandler are sitting at a table, Monica is checking her makeup as Chandler suddenly has a horrifying thought and starts patting down his pockets until he finds what he’s looking for and sighs in relief,
# 2   Joey and Chandler are playing foosball and Joey scores a goal,
# 3   Chandler has the tape measure out and is busy lining up the lamp on the kitchen counter, Ross is supervising the whole operation,
# 4   Rachel is still looking out the window as Joey enters,
#
#                                                                                                                                                  Text  \
# 0  You’re never gonna believe it uh, Monica and Chandler are moving in again. That’s great news right—I mean for them. Right?
# 1  Are you okay?
# 2  Yes!! Ha-ha!! All right! Hey! How cool would it be if you could watch like a real life-sized version of this? Huh? I mean how crazy would that be?
# 3  Look, we have no time okay? We must focus. We gotta get everything back into its original place.
# 4  Yeah you got 5 years left!
#
#     Speaker Season
# 0  Ross      6
# 1  Monica    6
# 2  Joey      6
# 3  Chandler  6
# 4  Joey      6

# %%
import re
friends_chars={} 
Rachel=''
Ross=''
Joey=''
Chandler=''
Phoebe=''
Monica=''
Scene=''
with open("transcripts_friends/season7/merged7.csv", "r+") as fp:
    for cnt, line in enumerate(fp):
        if line.startswith('[Scene:'):
            Scene=(line[7:].replace("]", "").replace(":", ",").replace(".", ","))
        if line.startswith('Rachel:'):
            string=Scene.replace("\n", "")+"*"+(line[8:].replace(":", ""))
            Rachel=Rachel+re.sub(r'\(.*\)', '', string)
        elif line.startswith('Ross:'):
            string=Scene.replace("\n", "")+"*"+(line[6:].replace(":", ""))
            Ross=Ross+re.sub(r'\(.*\)', '', string)
        elif line.startswith('Monica:'):
            string=Scene.replace("\n", "")+"*"+(line[8:].replace(":", ""))
            Monica=Monica+re.sub(r'\(.*\)', '', string)
        elif line.startswith('Chandler:'):
            string=Scene.replace("\n", "")+"*"+(line[10:].replace(":", ""))
            Chandler=Chandler+re.sub(r'\(.*\)', '', string)
        if line.startswith('Phoebe:'):
            string=Scene.replace("\n", "")+"*"+(line[8:].replace(":", ""))
            Phoebe=Phoebe+re.sub(r'\(.*\)', '', string)
        if line.startswith('Joey:'):
            string=Scene.replace("\n", "")+"*"+(line[6:].replace(":", ""))
            Joey=Joey+re.sub(r'\(.*\)', '', string)


friends_chars['RACHEL']=Rachel
friends_chars['ROSS']=Ross
friends_chars['MONICA']=Monica
friends_chars['PHOEBE']=Phoebe
friends_chars['CHANDLER']=Chandler
friends_chars['JOEY']=Joey

s=pd.Series(friends_chars['RACHEL'].split('\n'))
df1 = pd.DataFrame({'Text':s.values})
df1 = pd.DataFrame(df1.Text.str.split('*',1).tolist(), columns = ['Scene','Text'])
s=df1.Text
df1=  pd.DataFrame(df1.Scene.str.split(',',1).tolist(),
                                   columns = ['Location','Scene'])
df1['Text']=s
df1['Speaker']='Rachel'
df1['Season']='7'
df1.head(20)

s2=pd.Series(friends_chars['ROSS'].split('\n'))
df2 = pd.DataFrame({'Text':s2.values})
df2 = pd.DataFrame(df2.Text.str.split('*',1).tolist(), columns = ['Scene','Text'])
s=df2.Text
df2=  pd.DataFrame(df2.Scene.str.split(',',1).tolist(),
                                   columns = ['Location','Scene'])
df2['Text']=s
df2['Speaker']='Ross'
df2['Season']='7' 
df2.head(20)

s3=pd.Series(friends_chars['MONICA'].split('\n'))
df3 = pd.DataFrame({'Text':s3.values})
df3 = pd.DataFrame(df3.Text.str.split('*',1).tolist(), columns = ['Scene','Text'])
s=df3.Text
df3=  pd.DataFrame(df3.Scene.str.split(',',1).tolist(),
                                   columns = ['Location','Scene'])
df3['Text']=s
df3['Speaker']='Monica'
df3['Season']='7'                         
df3.head(20)

s4=pd.Series(friends_chars['JOEY'].split('\n'))
df4 = pd.DataFrame({'Text':s4.values})
df4 = pd.DataFrame(df4.Text.str.split('*',1).tolist(), columns = ['Scene','Text'])
s=df4.Text
df4=  pd.DataFrame(df4.Scene.str.split(',',1).tolist(),
                                   columns = ['Location','Scene'])
df4['Text']=s
df4['Speaker']='Joey'
df4['Season']='7'                            
df4.head(20)

s5=pd.Series(friends_chars['PHOEBE'].split('\n'))
df5 = pd.DataFrame({'Text':s5.values})
df5 = pd.DataFrame(df5.Text.str.split('*',1).tolist(), columns = ['Scene','Text'])
s=df5.Text
df5=  pd.DataFrame(df5.Scene.str.split(',',1).tolist(),
                                   columns = ['Location','Scene'])
df5['Text']=s
df5['Speaker']='Phoebe'
df5['Season']='7'                           
df5.head(20)

s6=pd.Series(friends_chars['CHANDLER'].split('\n'))
df6 = pd.DataFrame({'Text':s6.values})
df6 = pd.DataFrame(df6.Text.str.split('*',1).tolist(), columns = ['Scene','Text'])
s=df6.Text
df6=  pd.DataFrame(df6.Scene.str.split(',',1).tolist(),
                                   columns = ['Location','Scene'])
df6['Text']=s
df6['Speaker']='Chandler'
df6['Season']='7'                            
df6.head(20)

df_7 = pd.concat([df1, df2,df3,df4,df5,df6])
df_7 = df_7.sample(frac=1).reset_index(drop=True)

df_7.head()
# Out:
#              Location  \
# 0   Monica
# 1   Grammercy Bistero
# 2   Monica
# 3   Central Perk
# 4   Kleinmanâ€™s
#
#                                                                                                                                     Scene  \
# 0   Chandler, and Phoebe's, continued from before the commercial break, Monica is walking into the apartment followed by Ross and Rachel,
# 1   Ross and Kristen are waiting for their table to be ready, Ross is returning from talking to the matireâ€™d,
# 2   Chandler, and Phoebe's, Chandler is on the phone, Rachel and Monica are sitting in the kitchen,
# 3   Rachel is there as Ross enters with his all his hair sticking straight up,
# 4   a horde of women including Rachel, Phoebe, and Monica are waiting for the store to open,
#
#                                                                                                Text  \
# 0   Okay, I think Iâ€™ll play it at the wedding.
# 1  Yeah. Soâ€¦
# 2  Hey.
# 3  Did you see the look that girl just gave me? Huh? She mustâ€™ve seen me cruising in the bad boy.
# 4  Oh theyâ€™re pushing! Theyâ€™re pushing!!
#
#   Speaker Season
# 0  Phoebe  7
# 1  Ross    7
# 2  Joey    7
# 3  Ross    7
# 4  Rachel  7

# %%
import re
friends_chars={} 
Rachel=''
Ross=''
Joey=''
Chandler=''
Phoebe=''
Monica=''
Scene=''
with open("transcripts_friends/season8/merged8.csv", "r+") as fp:
    for cnt, line in enumerate(fp):
        if line.startswith('[Scene:'):
            Scene=(line[7:].replace("]", "").replace(":", ",").replace(".", ","))
        if line.startswith('Rachel:'):
            string=Scene.replace("\n", "")+"*"+(line[8:].replace(":", ""))
            Rachel=Rachel+re.sub(r'\(.*\)', '', string)
        elif line.startswith('Ross:'):
            string=Scene.replace("\n", "")+"*"+(line[6:].replace(":", ""))
            Ross=Ross+re.sub(r'\(.*\)', '', string)
        elif line.startswith('Monica:'):
            string=Scene.replace("\n", "")+"*"+(line[8:].replace(":", ""))
            Monica=Monica+re.sub(r'\(.*\)', '', string)
        elif line.startswith('Chandler:'):
            string=Scene.replace("\n", "")+"*"+(line[10:].replace(":", ""))
            Chandler=Chandler+re.sub(r'\(.*\)', '', string)
        if line.startswith('Phoebe:'):
            string=Scene.replace("\n", "")+"*"+(line[8:].replace(":", ""))
            Phoebe=Phoebe+re.sub(r'\(.*\)', '', string)
        if line.startswith('Joey:'):
            string=Scene.replace("\n", "")+"*"+(line[6:].replace(":", ""))
            Joey=Joey+re.sub(r'\(.*\)', '', string)


friends_chars['RACHEL']=Rachel
friends_chars['ROSS']=Ross
friends_chars['MONICA']=Monica
friends_chars['PHOEBE']=Phoebe
friends_chars['CHANDLER']=Chandler
friends_chars['JOEY']=Joey

s=pd.Series(friends_chars['RACHEL'].split('\n'))
df1 = pd.DataFrame({'Text':s.values})
df1 = pd.DataFrame(df1.Text.str.split('*',1).tolist(), columns = ['Scene','Text'])
s=df1.Text
df1=  pd.DataFrame(df1.Scene.str.split(',',1).tolist(),
                                   columns = ['Location','Scene'])
df1['Text']=s
df1['Speaker']='Rachel'
df1['Season']='8'
df1.head(20)

s2=pd.Series(friends_chars['ROSS'].split('\n'))
df2 = pd.DataFrame({'Text':s2.values})
df2 = pd.DataFrame(df2.Text.str.split('*',1).tolist(), columns = ['Scene','Text'])
s=df2.Text
df2=  pd.DataFrame(df2.Scene.str.split(',',1).tolist(),
                                   columns = ['Location','Scene'])
df2['Text']=s
df2['Speaker']='Ross'
df2['Season']='8' 
df2.head(20)

s3=pd.Series(friends_chars['MONICA'].split('\n'))
df3 = pd.DataFrame({'Text':s3.values})
df3 = pd.DataFrame(df3.Text.str.split('*',1).tolist(), columns = ['Scene','Text'])
s=df3.Text
df3=  pd.DataFrame(df3.Scene.str.split(',',1).tolist(),
                                   columns = ['Location','Scene'])
df3['Text']=s
df3['Speaker']='Monica'
df3['Season']='8'                         
df3.head(20)

s4=pd.Series(friends_chars['JOEY'].split('\n'))
df4 = pd.DataFrame({'Text':s4.values})
df4 = pd.DataFrame(df4.Text.str.split('*',1).tolist(), columns = ['Scene','Text'])
s=df4.Text
df4=  pd.DataFrame(df4.Scene.str.split(',',1).tolist(),
                                   columns = ['Location','Scene'])
df4['Text']=s
df4['Speaker']='Joey'
df4['Season']='8'                            
df4.head(20)

s5=pd.Series(friends_chars['PHOEBE'].split('\n'))
df5 = pd.DataFrame({'Text':s5.values})
df5 = pd.DataFrame(df5.Text.str.split('*',1).tolist(), columns = ['Scene','Text'])
s=df5.Text
df5=  pd.DataFrame(df5.Scene.str.split(',',1).tolist(),
                                   columns = ['Location','Scene'])
df5['Text']=s
df5['Speaker']='Phoebe'
df5['Season']='8'                           
df5.head(20)

s6=pd.Series(friends_chars['CHANDLER'].split('\n'))
df6 = pd.DataFrame({'Text':s6.values})
df6 = pd.DataFrame(df6.Text.str.split('*',1).tolist(), columns = ['Scene','Text'])
s=df6.Text
df6=  pd.DataFrame(df6.Scene.str.split(',',1).tolist(),
                                   columns = ['Location','Scene'])
df6['Text']=s
df6['Speaker']='Chandler'
df6['Season']='8'                            
df6.head(20)

df_8 = pd.concat([df1, df2,df3,df4,df5,df6])
df_8 = df_8.sample(frac=1).reset_index(drop=True)

df_8.head()
# Out:
#                             Location  \
# 0   A Street
# 1   Chandler and Monicaâ€™s bathroom
# 2   The Semi-Private Labor Room
# 3   Monica and Chandler's
# 4   Monica and Chandler's
#
#                                                                                                                                                Scene  \
# 0   Ross is walking past a newsstand and sees Rachel,
# 1   Both are sitting on opposite ends of the bathtub,
# 2   theyâ€™re brining in yet another woman,
# 3   Monica and Chandler are entering carrying groceries and find Phoebe already there standing in front of a huge object that has been gift wrapped,
# 4   Chandler is cooking as Rachel paces nervously,
#
#                                                                                         Text  \
# 0  Oh you did, there are twenty in here.
# 1  Youâ€™re not?
# 2  Uh Rachâ€¦
# 3  I got it for your wedding and I ordered it weeks ago, and it finally got here!
# 4  Yeahâ€”No wait! Joey no wait it is. Itâ€™s something. Itâ€™s-itâ€™s ummâ€¦itâ€™s my boss.
#
#     Speaker Season
# 0  Rachel    8
# 1  Chandler  8
# 2  Ross      8
# 3  Phoebe    8
# 4  Rachel    8

# %%
import re
friends_chars={} 
Rachel=''
Ross=''
Joey=''
Chandler=''
Phoebe=''
Monica=''
Scene=''
with open("transcripts_friends/season9/merged9.csv", "r+") as fp:
    for cnt, line in enumerate(fp):
        if line.startswith('[Scene:'):
            Scene=(line[7:].replace("]", "").replace(":", ",").replace(".", ","))
        if line.startswith('Rachel:'):
            string=Scene.replace("\n", "")+"*"+(line[8:].replace(":", ""))
            Rachel=Rachel+re.sub(r'\(.*\)', '', string)
        elif line.startswith('Ross:'):
            string=Scene.replace("\n", "")+"*"+(line[6:].replace(":", ""))
            Ross=Ross+re.sub(r'\(.*\)', '', string)
        elif line.startswith('Monica:'):
            string=Scene.replace("\n", "")+"*"+(line[8:].replace(":", ""))
            Monica=Monica+re.sub(r'\(.*\)', '', string)
        elif line.startswith('Chandler:'):
            string=Scene.replace("\n", "")+"*"+(line[10:].replace(":", ""))
            Chandler=Chandler+re.sub(r'\(.*\)', '', string)
        if line.startswith('Phoebe:'):
            string=Scene.replace("\n", "")+"*"+(line[8:].replace(":", ""))
            Phoebe=Phoebe+re.sub(r'\(.*\)', '', string)
        if line.startswith('Joey:'):
            string=Scene.replace("\n", "")+"*"+(line[6:].replace(":", ""))
            Joey=Joey+re.sub(r'\(.*\)', '', string)


friends_chars['RACHEL']=Rachel
friends_chars['ROSS']=Ross
friends_chars['MONICA']=Monica
friends_chars['PHOEBE']=Phoebe
friends_chars['CHANDLER']=Chandler
friends_chars['JOEY']=Joey

s=pd.Series(friends_chars['RACHEL'].split('\n'))
df1 = pd.DataFrame({'Text':s.values})
df1 = pd.DataFrame(df1.Text.str.split('*',1).tolist(), columns = ['Scene','Text'])
s=df1.Text
df1=  pd.DataFrame(df1.Scene.str.split(',',1).tolist(),
                                   columns = ['Location','Scene'])
df1['Text']=s
df1['Speaker']='Rachel'
df1['Season']='9'
df1.head(20)

s2=pd.Series(friends_chars['ROSS'].split('\n'))
df2 = pd.DataFrame({'Text':s2.values})
df2 = pd.DataFrame(df2.Text.str.split('*',1).tolist(), columns = ['Scene','Text'])
s=df2.Text
df2=  pd.DataFrame(df2.Scene.str.split(',',1).tolist(),
                                   columns = ['Location','Scene'])
df2['Text']=s
df2['Speaker']='Ross'
df2['Season']='9' 
df2.head(20)

s3=pd.Series(friends_chars['MONICA'].split('\n'))
df3 = pd.DataFrame({'Text':s3.values})
df3 = pd.DataFrame(df3.Text.str.split('*',1).tolist(), columns = ['Scene','Text'])
s=df3.Text
df3=  pd.DataFrame(df3.Scene.str.split(',',1).tolist(),
                                   columns = ['Location','Scene'])
df3['Text']=s
df3['Speaker']='Monica'
df3['Season']='9'                         
df3.head(20)

s4=pd.Series(friends_chars['JOEY'].split('\n'))
df4 = pd.DataFrame({'Text':s4.values})
df4 = pd.DataFrame(df4.Text.str.split('*',1).tolist(), columns = ['Scene','Text'])
s=df4.Text
df4=  pd.DataFrame(df4.Scene.str.split(',',1).tolist(),
                                   columns = ['Location','Scene'])
df4['Text']=s
df4['Speaker']='Joey'
df4['Season']='9'                            
df4.head(20)

s5=pd.Series(friends_chars['PHOEBE'].split('\n'))
df5 = pd.DataFrame({'Text':s5.values})
df5 = pd.DataFrame(df5.Text.str.split('*',1).tolist(), columns = ['Scene','Text'])
s=df5.Text
df5=  pd.DataFrame(df5.Scene.str.split(',',1).tolist(),
                                   columns = ['Location','Scene'])
df5['Text']=s
df5['Speaker']='Phoebe'
df5['Season']='9'                           
df5.head(20)

s6=pd.Series(friends_chars['CHANDLER'].split('\n'))
df6 = pd.DataFrame({'Text':s6.values})
df6 = pd.DataFrame(df6.Text.str.split('*',1).tolist(), columns = ['Scene','Text'])
s=df6.Text
df6=  pd.DataFrame(df6.Scene.str.split(',',1).tolist(),
                                   columns = ['Location','Scene'])
df6['Text']=s
df6['Speaker']='Chandler'
df6['Season']='9'                            
df6.head(20)

df_9 = pd.concat([df1, df2,df3,df4,df5,df6])
df_9 = df_9.sample(frac=1).reset_index(drop=True)

df_9.head()
# Out:
#                            Location  \
# 0   Ross's room
# 1   Shop
# 2   Outside the Nursery
# 3   At the counter
# 4   Monica and Chandler's apartment
#
#                                                                          Scene  \
# 0   Charlie is sitting on the bed, while Ross is walking up and down nervously
# 1   Rachel, Charlie and Phoebe walk in
# 2   everyone but Rachel is standing and looking into the window,
# 3   Ross is sitting there, drinking, Phoebe approaches him,
# 4  None
#
#                                                                                                                                                                    Text  \
# 0  And then, you try to make the best of a bad situation, so you float the idea of a threesome?
# 1  Pheebs, that's for men!
# 2  No! No, that was Jack! Rachel thinks I asked her to marry me!
# 3  Hey Ross! So listen, about you and the dinosaur girl, are you really just gonna let a couple of Nobel prizes scare you off? What is that, come on, a piece of paper?
# 4  We really need to take those tests?
#
#     Speaker Season
# 0  Ross      9
# 1  Rachel    9
# 2  Joey      9
# 3  Phoebe    9
# 4  Chandler  9

# %%
import re
friends_chars={} 
Rachel=''
Ross=''
Joey=''
Chandler=''
Phoebe=''
Monica=''
Scene=''
with open("transcripts_friends/season10/merged10.csv", "r+",encoding="utf8") as fp:
    for cnt, line in enumerate(fp):
        if line.startswith('[Scene:'):
            Scene=(line[7:].replace("]", "").replace(":", ",").replace(".", ","))
        if line.startswith('Rachel:'):
            string=Scene.replace("\n", "")+"*"+(line[8:].replace(":", ""))
            Rachel=Rachel+re.sub(r'\(.*\)', '', string)
        elif line.startswith('Ross:'):
            string=Scene.replace("\n", "")+"*"+(line[6:].replace(":", ""))
            Ross=Ross+re.sub(r'\(.*\)', '', string)
        elif line.startswith('Monica:'):
            string=Scene.replace("\n", "")+"*"+(line[8:].replace(":", ""))
            Monica=Monica+re.sub(r'\(.*\)', '', string)
        elif line.startswith('Chandler:'):
            string=Scene.replace("\n", "")+"*"+(line[10:].replace(":", ""))
            Chandler=Chandler+re.sub(r'\(.*\)', '', string)
        if line.startswith('Phoebe:'):
            string=Scene.replace("\n", "")+"*"+(line[8:].replace(":", ""))
            Phoebe=Phoebe+re.sub(r'\(.*\)', '', string)
        if line.startswith('Joey:'):
            string=Scene.replace("\n", "")+"*"+(line[6:].replace(":", ""))
            Joey=Joey+re.sub(r'\(.*\)', '', string)


friends_chars['RACHEL']=Rachel
friends_chars['ROSS']=Ross
friends_chars['MONICA']=Monica
friends_chars['PHOEBE']=Phoebe
friends_chars['CHANDLER']=Chandler
friends_chars['JOEY']=Joey

s=pd.Series(friends_chars['RACHEL'].split('\n'))
df1 = pd.DataFrame({'Text':s.values})
df1 = pd.DataFrame(df1.Text.str.split('*',1).tolist(), columns = ['Scene','Text'])
s=df1.Text
df1=  pd.DataFrame(df1.Scene.str.split(',',1).tolist(),
                                   columns = ['Location','Scene'])
df1['Text']=s
df1['Speaker']='Rachel'
df1['Season']='10'
df1.head(20)

s2=pd.Series(friends_chars['ROSS'].split('\n'))
df2 = pd.DataFrame({'Text':s2.values})
df2 = pd.DataFrame(df2.Text.str.split('*',1).tolist(), columns = ['Scene','Text'])
s=df2.Text
df2=  pd.DataFrame(df2.Scene.str.split(',',1).tolist(),
                                   columns = ['Location','Scene'])
df2['Text']=s
df2['Speaker']='Ross'
df2['Season']='10' 
df2.head(20)

s3=pd.Series(friends_chars['MONICA'].split('\n'))
df3 = pd.DataFrame({'Text':s3.values})
df3 = pd.DataFrame(df3.Text.str.split('*',1).tolist(), columns = ['Scene','Text'])
s=df3.Text
df3=  pd.DataFrame(df3.Scene.str.split(',',1).tolist(),
                                   columns = ['Location','Scene'])
df3['Text']=s
df3['Speaker']='Monica'
df3['Season']='10'                         
df3.head(20)

s4=pd.Series(friends_chars['JOEY'].split('\n'))
df4 = pd.DataFrame({'Text':s4.values})
df4 = pd.DataFrame(df4.Text.str.split('*',1).tolist(), columns = ['Scene','Text'])
s=df4.Text
df4=  pd.DataFrame(df4.Scene.str.split(',',1).tolist(),
                                   columns = ['Location','Scene'])
df4['Text']=s
df4['Speaker']='Joey'
df4['Season']='10'                            
df4.head(20)

s5=pd.Series(friends_chars['PHOEBE'].split('\n'))
df5 = pd.DataFrame({'Text':s5.values})
df5 = pd.DataFrame(df5.Text.str.split('*',1).tolist(), columns = ['Scene','Text'])
s=df5.Text
df5=  pd.DataFrame(df5.Scene.str.split(',',1).tolist(),
                                   columns = ['Location','Scene'])
df5['Text']=s
df5['Speaker']='Phoebe'
df5['Season']='10'                           
df5.head(20)

s6=pd.Series(friends_chars['CHANDLER'].split('\n'))
df6 = pd.DataFrame({'Text':s6.values})
df6 = pd.DataFrame(df6.Text.str.split('*',1).tolist(), columns = ['Scene','Text'])
s=df6.Text
df6=  pd.DataFrame(df6.Scene.str.split(',',1).tolist(),
                                   columns = ['Location','Scene'])
df6['Text']=s
df6['Speaker']='Chandler'
df6['Season']='10'                            
df6.head(20)

df_10 = pd.concat([df1, df2,df3,df4,df5,df6])
df_10 = df_10.sample(frac=1).reset_index(drop=True)

df_10.head()
# Out:
#                        Location  \
# 0   Monica’s apartment
# 1   Central Perk
# 2   Monica’s apartment
# 3   Joey and Rachel's apartment
# 4   We cut back to the present
#
#                                                                                                    Scene  \
# 0   Monica is cleaning with a vacuum and then she cleans it with a dust buster, The guys enter the room,
# 1   Phoebe's trying to teach Joey French, so she's sitting in front of him with the script in her hands,
# 2   Somebody knocks the door
# 3
# 4   The reunion where Chandler and Ross are talking,
#
#                                                                          Text  \
# 0  I knew he couldn't be with a woman for 45 minutes!!
# 1  Uh. It's not... quite what I'm saying.
# 2  What?
# 3  Oh! Get over it soldier, we've gotta do this!  Ok. Aha! You like that huh?
# 4
#
#     Speaker Season
# 0  Joey      10
# 1  Phoebe    10
# 2  Chandler  10
# 3  Rachel    10
# 4  Rachel    10

# %%
df = pd.concat([df_10, df_9,df_8,df_7,df_6,df_5,df_4,df_3,df_2,df_1])
df = df.sample(frac=1).reset_index(drop=True)

df.to_csv('friends_dataset.csv')
# Out:
# C:\Users\LENOVO\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """Entry point for launching an IPython kernel.

# %%
df.head(50)
# Out:
#                             Location  \
# 0    The Theatre
# 1    Central Perk
# 2    Monica and Rachel's
# 3    Joey and Rachel's
# 4    Monica and Chandler's
# 5    Joey and Rachel's
# 6    Monica and Rachel's
# 7    Monica and Rachel's
# 8    Monica and Chandler's
# 9    Monica and Chandler's
# 10   Central Perk
# 11   Joeyâ€™s
# 12   Monica and Chandler's
# 13   The Street
# 14   Monica and Rachel's
# 15   Monica and Rachel's
# 16   Monica and Chandler's apartment
# 17   Phoebe and Rachel's
# 18   Ross and Rachel's
# 19   Central Perk
# 20   Central Perk
# 21   Central Perk
# 22   The wedding rehearsal dinner
# 23   Monica and Rachel's
# 24   Chandler and Joey's
# 25   Barbados
# 26   Rachelâ€™s New Office
# 27   Central Perk
# 28   Monica and Rachel's erm
# 29   Monica and Chandler's
# 30   The Hospital
# 31   The hallway
# 32   Monica and Rachel's
# 33   The Launderama
# 34   Central Perk
# 35   The hallway
# 36   Central Perk
# 37   Monica and Chandler's
# 38   A Street
# 39   Chandler and Monicaâ€™s
# 40   Chandler and Joey's
# 41   Rachel's office
# 42   Central Perk
# 43   Central Perk
# 44   The Porsche
# 45   The breakfast buffet
# 46   Central Perk
# 47   Rachel’s Bedroom
# 48   Chandler and Joey's
# 49   Monica and Rachel's erm
#
#                                                                                                                                                         Scene  \
# 0    after the party, Joey is trying to comfort Kate,
# 1    Ross and Chandler are sitting at a table, Rachel is working, Monica and Phoebe enter,
# 2    everyone is sitting around the kitchen table,   Rachel's credit cards are spread out on the table along with a pair of scissors,
# 3   None
# 4    Monica, Chandler, Ross, and Rachel are sitting around the table,
# 5    Joey and Phoebe are moving chess pieces around on the board and hitting the timer at random,
# 6    Rachel is painting her toe nails as Monica enters,
# 7    Chandler, Joey, Phoebe, and Monica are watching Three's Company,
# 8    Monica and Chandler are entering carrying groceries and find Phoebe already there standing in front of a huge object that has been gift wrapped,
# 9    everyone except Phoebe is there as Rachel enters carrying a magazine,
# 10   Chandler is on the couch reading as Ross enters carrying a garment bag,
# 11   Joey is laying on his recliner, depressed, and the dog is laying on the footrest,
# 12   Monica has hit a writerâ€™s block as Rachel and Phoebe enter,
# 13   Chandler is carrying Monica past a store window,
# 14   Mark is there, opening Chinese food boxes,
# 15   Rachel is getting Phoebe ready for her date,
# 16   Monica, Chandler, Rachel and Joey are in the kitchen
# 17   Phoebe and Rachel are returning,
# 18   itâ€™s late at night, Rachel is sitting on the couch in the dark wide-awake as Ross walks to the bathroom,
# 19  None
# 20   Chandler and Monica are there when Phoebe enters,
# 21  None
# 22
# 23   Ross, Chandler, Monica, and Phoebe are eating breakfast,
# 24   Ross and Joey are standing and talking, Ross is tying a tie,
# 25   Monica and Chandler's Room, They both enter from Ross's room, Monica still has her big, frizzy hair,
# 26   sheâ€™s interviewing a potential new assistant, Hilda,
# 27   Joey, Monica, and Chandler are sitting on the couch and chair as Phoebe is getting coffee,
# 28   Chandler and Joey's, Ross is writing on the Magna-Doodle as Rachel enters,
# 29   Monica and Chandler are eating lunch, when they start to hear a horrible screeching noise, It sounds like someone is skinning a cat,
# 30   Joey is sitting in the lobby as Ross enters,
# 31   Ross is running up the stairs, Note, This show continues where the last one left off,
# 32   Phoebe is showing Monica where Sergei’s country is,
# 33   Rachel is there, waiting for Ross, An old woman takes Rachel's clothes off the machine and begins loading it with her things,
# 34   Ross is getting coffee at the counter, Chandler walks in,
# 35   Chandler is helping Monica to the door,
# 36   Ross is getting coffee as Joey comes fromâ€¦God knows where! Some back area of Central Perk around the corner that weâ€™ve never seen! Weeeiiirrrdddâ€¦,
# 37   scene continued from earlier,
# 38   Phoebe and Ross are exiting a pizza place,
# 39   theyâ€™re getting ready to leave for the party,
# 40   Chandler is helping Joey rehearse for a part,
# 41   Mark is training Rachel,
# 42   continued from earlier, Chandler is sitting on the table,
# 43   Phoebe's trying to teach Joey French, so she's sitting in front of him with the script in her hands,
# 44   they have pulled over and are awaiting the cop to come talk to them,
# 45   Phoebe is already sitting at the table as Joey enters,
# 46   continued from earlier, Ross is handing Rachel a cup of coffee,
# 47   Ross is finishing up her make-up,
# 48   they’re still playing Cups,
# 49   Chandler and Joey's, Ross is writing on the Magna-Doodle as Rachel enters,
#
#    Season   Speaker  \
# 0   3      Joey
# 1   1      Joey
# 2   1      Rachel
# 3   10     Rachel
# 4   7      Chandler
# 5   7      Rachel
# 6   6      Monica
# 7   1      Monica
# 8   8      Monica
# 9   8      Rachel
# 10  7      Ross
# 11  8      Joey
# 12  7      Chandler
# 13  8      Chandler
# 14  3      Ross
# 15  5      Chandler
# 16  9      Chandler
# 17  6      Ross
# 18  8      Rachel
# 19  3      Rachel
# 20  10     Phoebe
# 21  9      Monica
# 22  10     Rachel
# 23  5      Chandler
# 24  4      Joey
# 25  10     Rachel
# 26  7      Rachel
# 27  8      Phoebe
# 28  4      Phoebe
# 29  7      Monica
# 30  9      Ross
# 31  5      Ross
# 32  3      Ross
# 33  1      Rachel
# 34  10     Rachel
# 35  6      Monica
# 36  8      Ross
# 37  8      Phoebe
# 38  7      Ross
# 39  8      Rachel
# 40  1      Ross
# 41  3      Ross
# 42  1      Rachel
# 43  10     Monica
# 44  7      Rachel
# 45  6      Ross
# 46  3      Phoebe
# 47  3      Ross
# 48  6      Chandler
# 49  4      Ross
#
#                                                                                                                                                      Text
# 0   Oh, classy.
# 1   Yeah, we just don't happen to know any women that know how to play poker.
# 2   I did.
# 3   Aah... I bet you're right.
# 4   Donâ€™t do it.
# 5   Well, do you want to hear what actually happened or Joeyâ€™s lewd version?
# 6   But still, it’s a big change. The end of an era, you might say!
# 7   Easy Rach, we'll find it.  Won't we!
# 8   Oh my God!
# 9   Okay, donâ€™t listen to him. Please?
# 10  Pretty please? Not very uh, 007.
# 11  No, no, no, no! Heâ€™s fine! Look, look, look!  Get your ball! My God, what have I done to you, huh? I broke the dog! Pheebs, I broke the dog!
# 12  Yeah, Iâ€™m not sure I can do that.
# 13  Okay.
# 14  Hi! It’s me.
# 15  Okay, listen, how far am I gonna have to go with her?
# 16  Yes there are, I just saw them a few minutes ago.
# 17  It’s not something you are! It’s something you have!
# 18  Okay. Thank you. Thatâ€™s great. Thank you. Wait-wait! Where on west 10th? Because thereâ€™s this really cute shoe store that has like this littleâ€¦
# 19   Ross's what?
# 20  Oh, not anymore. I changed it today.
# 21  So, do you guys wanna come and eat dinner at the restaurant sometime in the next few weeks?
# 22  Yeah.
# 23  Thank you.
# 24  All right, so... next time, you take her to your place.
# 25  Yeah, sure...
# 26   Wow! H-umm! Hi! Yes, uh Iâ€™m sorry the models are actually down the hall.
# 27  Wow! Oh well, I will be there!
# 28  Oh my God!! The baby just kicked!
# 29  What is that?
# 30  Yes. I mean, itâ€™s what we always planned.  And if you have a plan, you should stick to it.  Thatâ€™s why they call them plans.  Hello?  Iâ€™m fine.
# 31   I thought you were my best friend, this is my sister! My best friend and my sister! I-I cannot believe this!
# 32  Oh what?! Is she gonna cancel on me again?! How can she do this? Doesn’t she know it’s our anniversary?
# 33  But I saved it. I put my basket on top.
# 34  Uh.
# 35  This doesn’t mean anything, does it?
# 36  Hey, hey, itâ€™s me. Why canâ€™t you tell me?
# 37  Oh!  Wow!
# 38  So this is your office?
# 39  Hi!
# 40  What is this?!
# 41  Why does Joanna need two assistants, how, how lazy is she?
# 42  Get off.
# 43  I want you to meet someone really special. Phoebe, this is Erica. And this is the baby!
# 44  Really?! You think so? Yâ€™know, I had just rolled out of bed.
# 45  Yeah!
# 46  Do I?
# 47  Ahh, sorry, nothing you can do about it. It’s one of my ah, rights as the ex-boyfriend.  Oop, oh yeah!
# 48  You win.
# 49  Monica said that did she?

# %%
df.shape
# Out:
# (93335, 5)

# %%
## # friends_chars={} 
# key1 = "Rachel"
# key2="Ross"
# key3="Monica"
# key4="Chandler"
# key5="Phoebe"
# key6="Joey"

# friends_chars.setdefault(key1, [])
# friends_chars.setdefault(key2, [])
# friends_chars.setdefault(key3, [])
# friends_chars.setdefault(key4, [])
# friends_chars.setdefault(key5, [])
# friends_chars.setdefault(key6, [])

# with open("transcripts_friends/season_all/merged.csv", "r+") as fp:
#     for cnt, line in enumerate(fp):
#         if line.startswith('Rachel:'):
#             friends_chars[key1].append(line[8:].replace("\n"," ").replace("\r",""))
#         elif line.startswith('Ross:'):
#             friends_chars[key2].append(line[6:].replace("\n"," ").replace("\r",""))
#         elif line.startswith('Monica:'):
#             friends_chars[key3].append(line[8:].replace("\n"," ").replace("\r",""))
#         elif line.startswith('Chandler:'):
#             friends_chars[key4].append(line[10:].replace("\n"," ").replace("\r",""))
#         if line.startswith('Phoebe:'):
#             friends_chars[key5].append(line[8:].replace("\n"," ").replace("\r",""))
#         if line.startswith('Joey:'):
#             friends_chars[key6].append(line[6:].replace("\n"," ").replace("\r",""))

# %%
friends_chars
# Out:
# {'RACHEL': ' The beach house, it’s the same scene from the end of last year, with Ross in front of the two doors of Rachel’s and Bonnie’s rooms, trying to decide which door to choose, He finally chooses the one his right and goes in,*Oh, you’re welcome a million.\n The beach house, it’s the same scene from the end of last year, with Ross in front of the two doors of Rachel’s and Bonnie’s rooms, trying to decide which door to choose, He finally chooses the one his right and goes in,* Oh my God.\n The beach house, it’s the same scene from the end of last year, with Ross in front of the two doors of Rachel’s and Bonnie’s rooms, trying to decide which door to choose, He finally chooses the one his right and goes in,*Whoa! What?! Why?!\n The beach house, it’s the same scene from the end of last year, with Ross in front of the two doors of Rachel’s and Bonnie’s rooms, trying to decide which door to choose, He finally chooses the one his right and goes in,*Here?! Now?!\n The beach house, it’s the same scene from the end of last year, with Ross in front of the two doors of Rachel’s and Bonnie’s rooms, trying to decide which door to choose, He finally chooses the one his right and goes in,*Well, can’t you tell her that you are not in the mood?\n The beach house, it’s the same scene from the end of last year, with Ross in front of the two doors of Rachel’s and Bonnie’s rooms, trying to decide which door to choose, He finally chooses the one his right and goes in,* Whoa-ho.\n The beach house, it’s the same scene from the end of last year, with Ross in front of the two doors of Rachel’s and Bonnie’s rooms, trying to decide which door to choose, He finally chooses the one his right and goes in,*I don’t know.\n The beach house, it’s the same scene from the end of last year, with Ross in front of the two doors of Rachel’s and Bonnie’s rooms, trying to decide which door to choose, He finally chooses the one his right and goes in,*Oh, making it worse!\n The beach house, Rachel’s bedroom, She is finishing up writing something as Ross walks through the door,*Oh, was it awful?\n The beach house, Rachel’s bedroom, She is finishing up writing something as Ross walks through the door,*I wrote you a letter.\n The beach house, Rachel’s bedroom, She is finishing up writing something as Ross walks through the door,* It’s just some things I’ve been thinking about. Some things about us, and before we can even think about the two of us getting back together, I just need to know how you feel about this stuff.\n The beach house, Rachel’s bedroom, She is finishing up writing something as Ross walks through the door,*Well, I’ll be waiting for you, just come up when you’re done.\n The beach house, the next morning, Ross is passed out on the kitchen counter, He wakes up with a start and has one of the pages of the letter stuck to his face,* What happened to you? Why didn’t you come up?\n The beach house, the next morning, Ross is passed out on the kitchen counter, He wakes up with a start and has one of the pages of the letter stuck to his face,*You just finished?\n The beach house, the next morning, Ross is passed out on the kitchen counter, He wakes up with a start and has one of the pages of the letter stuck to his face,*So umm, does it?\n The beach house, the next morning, Ross is passed out on the kitchen counter, He wakes up with a start and has one of the pages of the letter stuck to his face,*Does it?\n The beach house, the next morning, Ross is passed out on the kitchen counter, He wakes up with a start and has one of the pages of the letter stuck to his face,*What are you talking about, Ross, you just said that you read it twice! Look, y\'know what, either it does or it doesn’t, and if you have to even think about it...\n The beach house, the next morning, Ross is passed out on the kitchen counter, He wakes up with a start and has one of the pages of the letter stuck to his face,*Are you sure?\n The beach house, the next morning, Ross is passed out on  ...
#  'ROSS': ' The beach house, it’s the same scene from the end of last year, with Ross in front of the two doors of Rachel’s and Bonnie’s rooms, trying to decide which door to choose, He finally chooses the one his right and goes in,* Hi!\n The beach house, it’s the same scene from the end of last year, with Ross in front of the two doors of Rachel’s and Bonnie’s rooms, trying to decide which door to choose, He finally chooses the one his right and goes in,*Awww.\n The beach house, it’s the same scene from the end of last year, with Ross in front of the two doors of Rachel’s and Bonnie’s rooms, trying to decide which door to choose, He finally chooses the one his right and goes in,*Yeah. \n The beach house, it’s the same scene from the end of last year, with Ross in front of the two doors of Rachel’s and Bonnie’s rooms, trying to decide which door to choose, He finally chooses the one his right and goes in,*I know.\n The beach house, it’s the same scene from the end of last year, with Ross in front of the two doors of Rachel’s and Bonnie’s rooms, trying to decide which door to choose, He finally chooses the one his right and goes in,* Okay, I gotta go.\n The beach house, it’s the same scene from the end of last year, with Ross in front of the two doors of Rachel’s and Bonnie’s rooms, trying to decide which door to choose, He finally chooses the one his right and goes in,*Well, I-I gotta go break up with Bonnie.\n The beach house, it’s the same scene from the end of last year, with Ross in front of the two doors of Rachel’s and Bonnie’s rooms, trying to decide which door to choose, He finally chooses the one his right and goes in,*Well, yeah. I can’t-I can’t stay here all night, and if I go in there she’s-she’s gonna wanna... do stuff.\n The beach house, it’s the same scene from the end of last year, with Ross in front of the two doors of Rachel’s and Bonnie’s rooms, trying to decide which door to choose, He finally chooses the one his right and goes in,*No, she likes that. Yeah. Faking sleep doesn’t work either, I can’t tell you how many mornings I woke up with her...\n The beach house, it’s the same scene from the end of last year, with Ross in front of the two doors of Rachel’s and Bonnie’s rooms, trying to decide which door to choose, He finally chooses the one his right and goes in,*Whoa-oh, okay! Yeah, why am I telling you that?\n The beach house, it’s the same scene from the end of last year, with Ross in front of the two doors of Rachel’s and Bonnie’s rooms, trying to decide which door to choose, He finally chooses the one his right and goes in,*Yeah, yeah.  It wasn’t every morning.\n The beach house, it’s the same scene from the end of last year, with Ross in front of the two doors of Rachel’s and Bonnie’s rooms, trying to decide which door to choose, He finally chooses the one his right and goes in,*Okay.\n The beach house, Rachel’s bedroom, She is finishing up writing something as Ross walks through the door,*It’s over.\n The beach house, Rachel’s bedroom, She is finishing up writing something as Ross walks through the door,*Well, it was loong. I didn’t even realise how late it
n Monica and Rachel\'s, Chandler, Monica, and Joey are sitting at the table eating dinner and not talking, Ross and Rachel are outside cuddling on the balcony,*Nope.\n Monica and Rachel\'s, Chandler, Monica, and Joey are sitting at the table eating dinner and not talking, Ross and Rachel are outside cuddling on the balcony,*All right. \n Monica and Rachel\'s, Chandler, Monica, and Joey are sitting at the table eating dinner and not talking, Ross and Rachel are outside cuddling on the balcony,*Well, we have to say something! We have to get it out! It’s eating me alive!! Monica got stung by a jellyfish.\n Monica and Rachel\'s, Chandler, Monica, and Joey are sitting at the table eating dinner and not talking, Ross and Rachel are outside cuddling on the balcony,*And I was tired from digging the huge hole!\n Monica and Rachel\'s, Chandler, Monica, and Joey are sitting at the table eating dinner and not talking, Ross and Rachel are outside cuddling on the balcony,*I’d seen this thing on The Discovery Channel...\n Monica and Rachel\'s, Chandler, Monica, and Joey are sitting at the table eating dinner and not talking, Ross and Rachel are outside cuddling on the balcony,*That’s right I stepped up! She’s my friend and she needed help! And if I had too, I’d pee on anyone of you! Only, uhh, I couldn’t. I got the stage fright. I wanted to help, but there was too much pressure. So-so I uh, I turned to Chandler.\n Monica and Rachel\'s, Chandler, Monica, and Joey are sitting at the table eating dinner and not talking, Ross and Rachel are outside cuddling on the balcony,* That’s ‘cause sometimes I just do it through my wall to freak you out.\n Chandler and Joey\'s, Joey is eating breakfast as Chandler comes out of his bedroom, ripping his coat in the process,*How many times do I have to tell you! Ya, turn and sliiiide! Y\'know, turn and slide.\n Chandler and Joey\'s, Joey is eating breakfast as Chandler  ...

# %%
import json

with open('rachel.txt', 'w') as rachel:
    rachel.write(Rachel) 
rachel.close()

with open('monica.txt', 'w') as monica:
    monica.write(Monica) 
monica.close()

with open('ross.txt', 'w') as ross:
    ross.write(Ross) 
ross.close()

with open('phoebe.txt', 'w') as phoebe:
    phoebe.write(Phoebe) 
phoebe.close()

with open('joe.txt', 'w') as joe:
    joe.write(Joey) 
joe.close()

with open('chandler.txt', 'w') as chandler:
    chandler.write(Chandler) 
chandler.close()

# %%
df = pd.DataFrame([([k] + v) for k, v in friends_chars.items()], columns=['name','dialoguee'])
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-97-927c88ffe479> in <module>
# ----> 1 df = pd.DataFrame([([k] + v) for k, v in friends_chars.items()], columns=['name','dialoguee'])
#
# /usr/local/lib/python3.7/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     433                     if is_named_tuple(data[0]) and columns is None:
#     434                         columns = data[0]._fields
# --> 435                     arrays, columns = to_arrays(data, columns, dtype=dtype)
#     436                     columns = ensure_index(columns)
#     437
#
# /usr/local/lib/python3.7/site-packages/pandas/core/internals/construction.py in to_arrays(data, columns, coerce_float, dtype)
#     402     if isinstance(data[0], (list, tuple)):
#     403         return _list_to_arrays(data, columns, coerce_float=coerce_float,
# --> 404                                dtype=dtype)
#     405     elif isinstance(data[0], compat.Mapping):
#     406         return _list_of_dict_to_arrays(data, columns,
#
# /usr/local/lib/python3.7/site-packages/pandas/core/internals/construction.py in _list_to_arrays(data, columns, coerce_float, dtype)
#     434         content = list(lib.to_object_array(data).T)
#     435     return _convert_object_array(content, columns, dtype=dtype,
# --> 436                                  coerce_float=coerce_float)
#     437
#     438
#
# /usr/local/lib/python3.7/site-packages/pandas/core/internals/construction.py in _convert_object_array(content, columns, coerce_float, dtype)
#     490             raise AssertionError('{col:d} columns passed, passed data had '
#     491                                  '{con} columns'.format(col=len(columns),
# --> 492                                                         con=len(content)))
#     493
#     494     # provide soft conversion of object dtypes
#
# AssertionError: 2 columns passed, passed data had 18075 columns

# %%
df=pd.DataFrame()
with open('rachel.txt', 'r') as rachel:
    for cnt, line in enumerate(rachel):
        tokens=line.split(':')
        df['Character']=tokens[0]
        df['text']=tokens[1]
        print(df.head())
rachel.close()

# cols=['Dialogue', 'Character']
# df=df[cols]
# Out:
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# ...
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []
# Empty DataFrame
# Columns: [Character, text]
# Index: []

# %%
df.head()
# Out:
# Empty DataFrame
# Columns: []
# Index: []
